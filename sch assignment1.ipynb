# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,12,26)
y=np.linspace(0,30,100)
y=10*np.sin(2*x)+10*np.cos(x)
plt.grid()
plt.plot(x,y)
plt.show()

# %%
import math
from mpl_toolkits import mplot3d

ax = plt.axes(projection ='3d')
n1=float(input())
n2=float(input())
def f(x, y):
    return (1/3.14)*math.sqrt(0.667)*np.sin(n1*x/2)*np.sin(n2*y/3)
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
z=np.linspace(-1,1,100)
X,Y=np.meshgrid(x,y)
Z = f(X, Y)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
surface_plot=ax.plot_surface(X,Y,Z)
plt.show()
# Out:
# 1
# 2

# %%
import numpy as np
x=[]
n=int(input())
for i in range(n):
    y=int(input())
    x.append(y)
x=np.array(x)
y=int(n/2)
for i in range(y):
    t=x[i]
    x[i]=x[n-i-1]
    x[n-i-1]=t
print(x)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5
# [5 4 3 2 1]

# %%
def det(a):
    det=a[0][0]*(a[1][1]*a[2][2]-a[2][1]*a[1][2])-a[0][1]*(a[1][0]*a[2][2]-a[2][0]*a[1][2])+a[0][2]*(a[1][0]*a[2][1]-a[2][0]*a[1][1])
    return det
det([[1,2,3],[4,5,6],[7,8,9]])
# Out:
# 0
